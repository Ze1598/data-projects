# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.26.0 to work with dp-100-study-jc

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8933333333333333
# AUC: 0.8801034877357082
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# azureml_globaldatasets - Default = False
# workspaceblobstore - Default = True
# workspacefilestore - Default = False
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 37 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 38 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 41 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 42 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 43 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 44 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 45 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 46 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 47 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 48 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 49 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 50 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 53 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 60 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 61 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 62 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "dp-100-study-jc"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Overwriting batch_pipeline/batch_diabetes.py

# %% [markdown]
# Next we'll define a run context that includes the dependencies required by the script

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core.runconfig import CondaDependencies

# Add dependencies required by the model
# For scikit-learn models, you need scikit-learn
# For parallel pipeline steps, you need azureml-core and azureml-dataprep[fuse]
cd = CondaDependencies.create(conda_packages=['scikit-learn','pip'],
                              pip_packages=['azureml-defaults','azureml-core','azureml-dataprep[fuse]'])

batch_env = Environment(name='batch_environment')
batch_env.python.conda_dependencies = cd
batch_env.docker.enabled = True
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import PipelineData

default_ds = ws.get_default_datastore()
# Create a PipelineData object that references the datastore
output_dir = PipelineData(name='inferences', 
                          datastore=default_ds, 
                          output_path_on_compute='diabetes/results')

# Set up step configuration
parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=1)

# Define the step
parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [8468ecf4][b25e75e1-7075-49f9-aab5-e147c30b58de], (This step is eligible to reuse a previous run's output)
# Submitted PipelineRun 3797e9ba-4b56-4353-bde7-972efe1aa0d4
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/3797e9ba-4b56-4353-bde7-972efe1aa0d4?wsid=/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourcegroups/dp-100-study-jc/workspaces/dp-100-study-jc&tid=d51de596-45a0-4aa5-a0d8-47d1c958aa32
# PipelineRunId: 3797e9ba-4b56-4353-bde7-972efe1aa0d4
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/3797e9ba-4b56-4353-bde7-972efe1aa0d4?wsid=/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourcegroups/dp-100-study-jc/workspaces/dp-100-study-jc&tid=d51de596-45a0-4aa5-a0d8-47d1c958aa32
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 09c088de-a311-4681-8490-add6939b43ac
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/09c088de-a311-4681-8490-add6939b43ac?wsid=/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourcegroups/dp-100-study-jc/workspaces/dp-100-study-jc&tid=d51de596-45a0-4aa5-a0d8-47d1c958aa32
# StepRun( batch-score-diabetes ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/05/07 14:27:01 Downloading source code...
# 2021/05/07 14:27:03 Finished downloading source code
# 2021/05/07 14:27:03 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/05/07 14:27:03 Successfully set up Docker network: acb_default_network
# 2021/05/07 14:27:03 Setting up Docker configuration...
# 2021/05/07 14:27:04 Successfully set up Docker configuration
# 2021/05/07 14:27:04 Logging in to registry: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io
# 2021/05/07 14:27:05 Successfully logged into 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io
# 2021/05/07 14:27:05 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/07 14:27:05 Scanning for dependencies...
# 2021/05/07 14:27:06 Successfully scanned dependencies
# 2021/05/07 14:27:06 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#  ---> c942df5ba5d0
# Step 2/18 : USER root
#  ---> Running in 41394ddc5e6a
# Removing intermediate container 41394ddc5e6a
#  ---> c0d740d38a2e
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 0d8b999182ea
# Removing intermediate container 0d8b999182ea
#  ---> ce208b6eb5e6
# Step 4/18 : WORKDIR /
#  ---> Running in b612265f436f
# Removing intermediate container b612265f436f
#  ---> bb5168459b4c
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 6260e1d9523c
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 82564a477372
# Removing intermediate container 82564a477372
#  ---> 66a5b68b2d16
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
# StepRun( batch-score-diabetes ) Status: Running
#  ---> 109b2407d24a
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_9f1642b367279a8b0eac354da8f073c0 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 455fc4c3db31
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ##8        |  29%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #######6   |  77%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##         |  21%
# python-3.6.2         | 27.0 MB   | ######5    |  66%
# python-3.6.2         | 27.0 MB   | #########7 |  97%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | #####7     |  58%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | #########7 |  98%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   2%
# mkl-2019.4           | 204.1 MB  | 7          |   8%
# mkl-2019.4           | 204.1 MB  | #2         |  13%
# mkl-2019.4           | 204.1 MB  | #7         |  18%
# mkl-2019.4           | 204.1 MB  | ##1        |  21%
# mkl-2019.4           | 204.1 MB  | ##6        |  27%
# mkl-2019.4           | 204.1 MB  | ###1       |  32%
# mkl-2019.4           | 204.1 MB  | ###7       |  38%
# mkl-2019.4           | 204.1 MB  | ####3      |  43%
# mkl-2019.4           | 204.1 MB  | ####8      |  49%
# mkl-2019.4           | 204.1 MB  | #####4     |  55%
# mkl-2019.4           | 204.1 MB  | #####9     |  60%
# mkl-2019.4           | 204.1 MB  | ######5    |  65%
# mkl-2019.4           | 204.1 MB  | #######1   |  71%
# mkl-2019.4           | 204.1 MB  | #######6   |  77%
# mkl-2019.4           | 204.1 MB  | ########2  |  82%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_9f1642b367279a8b0eac354da8f073c0/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.rmc2lwn5.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.26.0
#   Downloading azureml_defaults-1.26.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-core~=1.26.0
#   Downloading azureml_core-1.26.0-py3-none-any.whl (2.2 MB)
# Collecting azureml-dataprep[fuse]
#   Downloading azureml_dataprep-2.15.0-py3-none-any.whl (39.4 MB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.26.0
#   Downloading azureml_dataset_runtime-1.26.0-py3-none-any.whl (3.4 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting requests<3.0.0,>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.1.0-py2.py3-none-any.whl (1.1 MB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting docker
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-rslex<1.14.0a,>=1.13.0dev0
#   Downloading azureml_dataprep_rslex-1.13.0-cp36-cp36m-manylinux1_x86_64.whl (9.8 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<34.0.0,>=33.0.0
#   Downloading azureml_dataprep_native-33.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Requirement already satisfied, skipping upgrade: numpy!=1.19.3; sys_platform == "linux" in /azureml-envs/azureml_9f1642b367279a8b0eac354da8f073c0/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.26.0->azureml-defaults~=1.26.0->-r /azureml-environment-setup/condaenv.rmc2lwn5.requirements.txt (line 1)) (1.19.1)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_9f1642b367279a8b0eac354da8f073c0/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.26.0->-r /azureml-environment-setup/condaenv.rmc2lwn5.requirements.txt (line 1)) (1.15.0)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_9f1642b367279a8b0eac354da8f073c0/lib/python3.6/site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.26.0->-r /azureml-environment-setup/condaenv.rmc2lwn5.requirements.txt (line 2)) (2020.6.20)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.0.1-py3-none-any.whl (16 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.59.0-py2.py3-none-any.whl (67 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.13.0-py2.py3-none-any.whl (133 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.11.0-py2.py3-none-any.whl (63 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=d1774fcf0c9da4c9125875e683117fb2b1ee5c90dfeb770a7c332ba436e8e7ce
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=1396a8f236777257467febce1f506a40a95db5f2c1f78b5b54894cb4da8bc7c4
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=4ae6bda4889734014a3dd252eaa6803ac047772a7c8bbd9e5a15a975d34a6ee7
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: applicationinsights, werkzeug, distro, dotnetcore2, azureml-dataprep-rslex, idna, chardet, urllib3, requests, azure-core, pycparser, cffi, cryptography, PyJWT, msal, portalocker, msal-extensions, azure-identity, cloudpickle, azureml-dataprep-native, fusepy, azureml-dataprep, pyarrow, azureml-dataset-runtime, itsdangerous, MarkupSafe, Jinja2, click, flask, json-logging-py, gunicorn, configparser, dill, pytz, python-dateutil, pandas, liac-arff, adal, azureml-model-management-sdk, oauthlib, requests-oauthlib, isodate, msrest, msrestazure, jeepney, SecretStorage, jmespath, azure-common, azure-graphrbac, zipp, typing-extensions, importlib-metadata, jsonpickle, ruamel.yaml.clib, ruamel.yaml, pathspec, contextlib2, azure-mgmt-storage, backports.weakref, backports.tempfile, azure-mgmt-resource, pyopenssl, azure-mgmt-keyvault, azure-mgmt-containerregistry, pyasn1, ndg-httpsclient, websocket-client, docker, azure-mgmt-authorization, azureml-core, azureml-defaults
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.13.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.1.0 azure-mgmt-storage-11.2.0 azureml-core-1.26.0 azureml-dataprep-2.15.0 azureml-dataprep-native-33.0.0 azureml-dataprep-rslex-1.13.0 azureml-dataset-runtime-1.26.0 azureml-defaults-1.26.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.7 dill-0.3.3 distro-1.5.0 docker-5.0.0 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-4.0.1 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.11.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pandas-1.1.5 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 python-dateutil-2.8.1 pytz-2021.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 typing-extensions-3.10.0.0 urllib3-1.26.4 websocket-client-0.59.0 werkzeug-1.0.1 zipp-3.4.1
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_9f1642b367279a8b0eac354da8f073c0
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 455fc4c3db31
#  ---> 5784acff31a8
# Step 9/18 : ENV PATH /azureml-envs/azureml_9f1642b367279a8b0eac354da8f073c0/bin:$PATH
#  ---> Running in 966c2e936d62
# Removing intermediate container 966c2e936d62
#  ---> 417ddba830b9
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> b3c9ecd4d8bd
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> a81e60a537a3
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_9f1642b367279a8b0eac354da8f073c0
#  ---> Running in 33472af9eed4
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 33472af9eed4
#  ---> 291761d81770
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_9f1642b367279a8b0eac354da8f073c0
#  ---> Running in f6e53a60c02d
# Removing intermediate container f6e53a60c02d
#  ---> ac09ebd43486
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_9f1642b367279a8b0eac354da8f073c0/lib:$LD_LIBRARY_PATH
#  ---> Running in 2e25249c9dab
# Removing intermediate container 2e25249c9dab
#  ---> 0aaf0018bea5
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> fdaedbce37ae
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 1ffd177ea349
# Removing intermediate container 1ffd177ea349
#  ---> 7e9675230c9e
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 648d8da9deed
# Removing intermediate container 648d8da9deed
#  ---> b55df2cb59f2
# Step 18/18 : CMD ["bash"]
#  ---> Running in edcdf21a4f33
# Removing intermediate container edcdf21a4f33
#  ---> 37d99a342b1b
# Successfully built 37d99a342b1b
# Successfully tagged 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_68fbdb2037d3997a545af8e87c6ca620:latest
# Successfully tagged 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_68fbdb2037d3997a545af8e87c6ca620:1
# 2021/05/07 14:30:19 Successfully executed container: acb_step_0
# 2021/05/07 14:30:19 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/07 14:30:19 Pushing image: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_68fbdb2037d3997a545af8e87c6ca620:1, attempt 1
# The push refers to repository [94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_68fbdb2037d3997a545af8e87c6ca620]
# 68d886dbd093: Preparing
# 5ea2af527183: Preparing
# af8061bd598f: Preparing
# 9fe56034f508: Preparing
# 2de9a9af5fc8: Preparing
# 7fafe27213c1: Preparing
# 2f52a0ff29e4: Preparing
# 5975625d6e28: Preparing
# dab9cc7fdea7: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# 7fafe27213c1: Waiting
# 2f52a0ff29e4: Waiting
# 5975625d6e28: Waiting
# dab9cc7fdea7: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# 9fe56034f508: Pushed
# 68d886dbd093: Pushed
# af8061bd598f: Pushed
# 5ea2af527183: Pushed
# 7fafe27213c1: Pushed
# 5975625d6e28: Pushed
# 2f52a0ff29e4: Pushed
# dab9cc7fdea7: Pushed
# 3f3f8889d538: Pushed
# 420340de7040: Pushed
# c3d9b0d7dd4c: Pushed
# 18c9012f327d: Pushed
# 4441896e1280: Pushed
# 5276d2b930fc: Pushed
# e6feec0db89a: Pushed
# 697949baa658: Pushed
# 0d34930f20d5: Pushed
# a64fe594a899: Pushed
# 935c56d8b3f9: Pushed
# e4a0bf630548: Pushed
# 2de9a9af5fc8: Pushed
# 1: digest: sha256:6485fac158805ee2310f668774fe502af1ed2015620bd4123bee88c4498387d7 size: 4721
# 2021/05/07 14:32:38 Successfully pushed image: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_68fbdb2037d3997a545af8e87c6ca620:1
# 2021/05/07 14:32:38 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/07 14:32:38 Pushing image: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_68fbdb2037d3997a545af8e87c6ca620:latest, attempt 1
# The push refers to repository [94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_68fbdb2037d3997a545af8e87c6ca620]
# 68d886dbd093: Preparing
# 5ea2af527183: Preparing
# af8061bd598f: Preparing
# 9fe56034f508: Preparing
# 2de9a9af5fc8: Preparing
# 7fafe27213c1: Preparing
# 2f52a0ff29e4: Preparing
# 5975625d6e28: Preparing
# dab9cc7fdea7: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# 7fafe27213c1: Waiting
# 2f52a0ff29e4: Waiting
# 5975625d6e28: Waiting
# dab9cc7fdea7: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# a64fe594a899: Waiting
# e6feec0db89a: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# af8061bd598f: Layer already exists
# 5ea2af527183: Layer already exists
# 68d886dbd093: Layer already exists
# 2de9a9af5fc8: Layer already exists
# 9fe56034f508: Layer already exists
# 2f52a0ff29e4: Layer already exists
# dab9cc7fdea7: Layer already exists
# 5975625d6e28: Layer already exists
# 7fafe27213c1: Layer already exists
# 3f3f8889d538: Layer already exists
# 420340de7040: Layer already exists
# 4441896e1280: Layer already exists
# c3d9b0d7dd4c: Layer already exists
# a64fe594a899: Layer already exists
# e4a0bf630548: Layer already exists
# 18c9012f327d: Layer already exists
# 0d34930f20d5: Layer already exists
# 5276d2b930fc: Layer already exists
# 697949baa658: Layer already exists
# e6feec0db89a: Layer already exists
# 935c56d8b3f9: Layer already exists
# latest: digest: sha256:6485fac158805ee2310f668774fe502af1ed2015620bd4123bee88c4498387d7 size: 4721
# 2021/05/07 14:32:45 Successfully pushed image: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_68fbdb2037d3997a545af8e87c6ca620:latest
# 2021/05/07 14:32:45 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 194.248219)
# 2021/05/07 14:32:45 Populating digests for step ID: acb_step_0...
# 2021/05/07 14:32:48 Successfully populated digests for step ID: acb_step_0
# 2021/05/07 14:32:48 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 138.430482)
# 2021/05/07 14:32:48 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 7.010325)
# 2021/05/07 14:32:48 The following dependencies were found:
# 2021/05/07 14:32:48
# - image:
#     registry: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io
#     repository: azureml/azureml_68fbdb2037d3997a545af8e87c6ca620
#     tag: latest
#     digest: sha256:6485fac158805ee2310f668774fe502af1ed2015620bd4123bee88c4498387d7
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
# - image:
#     registry: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io
#     repository: azureml/azureml_68fbdb2037d3997a545af8e87c6ca620
#     tag: "1"
#     digest: sha256:6485fac158805ee2310f668774fe502af1ed2015620bd4123bee88c4498387d7
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
#
# Run ID: db5 was successful after 5m47s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_59dacfb0f60d5d85e4c106fb735c767f3fdd5d7adb7cd2f2b217d08e0a4ecad2_d.txt
# ========================================================================================================================
# 2021-05-07T14:33:16Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/mounts/workspaceblobstore
# 2021-05-07T14:33:16Z Starting output-watcher...
# 2021-05-07T14:33:17Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-07T14:33:17Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-05-07T14:33:17Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_4539de3ccb169db6707c8cade7afe14c
# 4007a89234b4: Already exists
# 5dfa26c6b9c9: Already exists
# 0ba7bf18aa40: Already exists
# 4c6ec688ebe3: Already exists
# 574f361512d6: Already exists
# db4d1e2d7079: Already exists
# e544ee0f522d: Already exists
# c655136086be: Already exists
# 2ec37f44090c: Already exists
# 5fba3bd4a2c4: Already exists
# 7e0ea9d0a1ab: Already exists
# da005f826951: Already exists
# ac4e1c91b241: Pulling fs layer
# efb648489c68: Pulling fs layer
# e5e2bb35fef1: Pulling fs layer
# 41f64f9d12ca: Pulling fs layer
# 404e390f8ac9: Pulling fs layer
# 00d1c09f699a: Pulling fs layer
# 41f64f9d12ca: Waiting
# 404e390f8ac9: Waiting
# 00d1c09f699a: Waiting
# e5e2bb35fef1: Download complete
# ac4e1c91b241: Verifying Checksum
# ac4e1c91b241: Download complete
# 41f64f9d12ca: Verifying Checksum
# 41f64f9d12ca: Download complete
# 00d1c09f699a: Verifying Checksum
# 00d1c09f699a: Download complete
# 404e390f8ac9: Verifying Checksum
# 404e390f8ac9: Download complete
# ac4e1c91b241: Pull complete
# efb648489c68: Verifying Checksum
# efb648489c68: Download complete
# efb648489c68: Pull complete
# e5e2bb35fef1: Pull complete
# 41f64f9d12ca: Pull complete
# 404e390f8ac9: Pull complete
# 00d1c09f699a: Pull complete
# Digest: sha256:a42e3315fb9cd2730a052be10a9492e8f265703745b1e8029604c5c178f93426
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c:latest
# viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c:latest
# 2021-05-07T14:33:26Z Check if container 09c088de-a311-4681-8490-add6939b43ac_DataSidecar already exist exited with 0,
#
# 7a9e8d8799f5299a191ac65755549da1a492a4b058fefab5e29b368c13f2e03b
# 2021-05-07T14:33:32Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-05-07T14:33:32Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-3836bd8afa326755f4d42970708223c1-78409e01b87afea2-01 -sshRequired=false]
# 2021/05/07 14:33:32 Starting App Insight Logger for task:  containerSetup
# 2021/05/07 14:33:32 Version: 3.0.01576.0004 Branch: .SourceBranch Commit: 5216581
# 2021/05/07 14:33:32 Entered ContainerSetupTask - Preparing infiniband
# 2021/05/07 14:33:32 Starting infiniband setup
# 2021/05/07 14:33:32 Python Version found is Python 3.7.9
#
# 2021/05/07 14:33:32 Returning Python Version as 3.7
# 2021/05/07 14:33:32 VMSize: standard_ds11_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/05/07 14:33:32 VMSize: standard_ds11_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021-05-07T14:33:32Z VMSize: standard_ds11_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/05/07 14:33:32 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/05/07 14:33:32 Not setting up Infiniband in Container
# 2021/05/07 14:33:32 Not setting up Infiniband in Container
# 2021-05-07T14:33:32Z Not setting up Infiniband in Container
# 2021/05/07 14:33:32 Python Version found is Python 3.7.9
#
# 2021/05/07 14:33:32 Returning Python Version as 3.7
# 2021/05/07 14:33:32 sshd inside container not required for job, skipping setup.
#
# Streaming azureml-logs/65_job_prep-tvmps_59dacfb0f60d5d85e4c106fb735c767f3fdd5d7adb7cd2f2b217d08e0a4ecad2_d.txt
# ===============================================================================================================
# [2021-05-07T14:33:33.838648] Entering job preparation.
# [2021-05-07T14:33:34.627306] Starting job preparation.
# [2021-05-07T14:33:34.627635] Extracting the control code.
# [2021-05-07T14:33:34.646345] fetching and extracting the control code on master node.
# [2021-05-07T14:33:34.646629] Starting extract_project.
# [2021-05-07T14:33:34.646978] Starting to extract zip file.
# [2021-05-07T14:33:35.086532] Finished extracting zip file.
# [2021-05-07T14:33:35.229491] Using urllib.request Python 3.0 or later
# [2021-05-07T14:33:35.229560] Start fetching snapshots.
# [2021-05-07T14:33:35.229612] Start fetching snapshot.
# [2021-05-07T14:33:35.229717] Retrieving project from snapshot: 4d046165-648b-40de-a23c-989327fc48c6
# Starting the daemon thread to refresh tokens in background for process with pid = 33
# [2021-05-07T14:33:35.464631] Finished fetching snapshot.
# [2021-05-07T14:33:35.464665] Start fetching snapshot.
# [2021-05-07T14:33:35.464939] Retrieving project from snapshot: bbd91160-1169-4f63-9b82-06426c5caf4b
# [2021-05-07T14:33:44.099773] Finished fetching snapshot.
# [2021-05-07T14:33:44.099814] Finished fetching snapshots.
# [2021-05-07T14:33:44.099824] Finished extract_project.
# [2021-05-07T14:33:44.110343] Finished fetching and extracting the control code.
# [2021-05-07T14:33:44.124486] Start run_history_prep.
# [2021-05-07T14:33:44.169876] Job preparation is complete.
# [2021-05-07T14:33:44.170008] Entering Data Context Managers in Sidecar
# [2021-05-07T14:33:44.170679] Running Sidecar prep cmd...
# [2021-05-07T14:33:44.579399] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/mounts/workspaceblobstore/azureml/09c088de-a311-4681-8490-add6939b43ac
# [2021-05-07T14:33:44.580349] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets", "DataStoreCopy:context_managers.DataStores"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.26.0 azureml-dataprep==2.14.2. Session id: c8d9ad82-1147-4e8b-be86-9e80215cd79c. Run id: 09c088de-a311-4681-8490-add6939b43ac.
# Processing 'diabetes_batch'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "63539e99-5a72-48c0-95c8-17ea9adbb17d",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='dp-100-study-jc', subscription_id='df741348-6c47-45d1-9bfc-1b8dbf6a4efa', resource_group='dp-100-study-jc')"
#   }
# }
# Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/wd/tmpmc7u3pnh.
# Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/wd/tmpmc7u3pnh as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/wd/tmpmc7u3pnh
# Acquired lockfile /tmp/09c088de-a311-4681-8490-add6939b43ac-datastore.lock to downloading input data references
# [2021-05-07T14:33:57.414874] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-05-07T14:33:58.555226] Ran Sidecar prep cmd.
# [2021-05-07T14:33:58.555303] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/05/07 14:34:48 Starting App Insight Logger for task:  runTaskLet
# 2021/05/07 14:34:48 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/05/07 14:34:48 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-05-07T14:34:49.543026] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.26.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/mounts/workspaceblobstore/azureml/09c088de-a311-4681-8490-add6939b43ac/inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# [2021-05-07T14:34:50.909932] Entering Run History Context Manager.
# [2021-05-07T14:34:51.569287] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/mounts/workspaceblobstore/azureml/09c088de-a311-4681-8490-add6939b43ac
# [2021-05-07T14:34:51.569531] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.26.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/mounts/workspaceblobstore/azureml/09c088de-a311-4681-8490-add6939b43ac/inferences', '--input_fds_0', 'diabetes_batch']
# [2021-05-07T14:34:51.569609] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.26.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/mounts/workspaceblobstore/azureml/09c088de-a311-4681-8490-add6939b43ac/inferences', '--input_fds_0', 'diabetes_batch']
#
# 2021/05/07 14:34:53 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
# Streaming azureml-logs/75_job_post-tvmps_59dacfb0f60d5d85e4c106fb735c767f3fdd5d7adb7cd2f2b217d08e0a4ecad2_d.txt
# ===============================================================================================================
# [2021-05-07T14:35:41.250213] Entering job release
# [2021-05-07T14:35:42.582775] Starting job release
# [2021-05-07T14:35:42.583485] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 250
# [2021-05-07T14:35:42.584401] job release stage : upload_datastore starting...
# [2021-05-07T14:35:42.584815] job release stage : start importing azureml.history._tracking in run_history_release.[2021-05-07T14:35:42.585078] job release stage : copy_batchai_cached_logs starting...
# [2021-05-07T14:35:42.585128] job release stage : copy_batchai_cached_logs completed...
#
# [2021-05-07T14:35:42.595526] job release stage : execute_job_release starting...
# [2021-05-07T14:35:42.650894] Entering context manager injector.
# [2021-05-07T14:35:42.694617] job release stage : send_run_telemetry starting...
# [2021-05-07T14:35:42.703395] job release stage : upload_datastore completed...
# [2021-05-07T14:35:42.722510] job release stage : execute_job_release completed...
# [2021-05-07T14:35:42.840959] get vm size and vm region successfully.
# [2021-05-07T14:35:42.860556] get compute meta data successfully.
# [2021-05-07T14:35:43.024698] post artifact meta request successfully.
# [2021-05-07T14:35:43.088548] upload compute record artifact successfully.
# [2021-05-07T14:35:43.088641] job release stage : send_run_telemetry completed...
# [2021-05-07T14:35:43.089114] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-05-07T14:35:43.089215] Running Sidecar release cmd...
# [2021-05-07T14:35:43.101097] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/mounts/workspaceblobstore/azureml/09c088de-a311-4681-8490-add6939b43ac
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/wd/tmpmc7u3pnh.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/09c088de-a311-4681-8490-add6939b43ac/wd/tmpmc7u3pnh.
# Exit __exit__ of DatasetContextManager
# [2021-05-07T14:35:43.175146] Removing absolute paths from host...
# [2021-05-07T14:35:43.182277] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-05-07T14:35:43.590989] Ran Sidecar release cmd.
# [2021-05-07T14:35:43.591090] Job release is complete
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '09c088de-a311-4681-8490-add6939b43ac', 'target': 'dp-100-study-jc', 'status': 'Completed', 'startTimeUtc': '2021-05-07T14:33:17.631879Z', 'endTimeUtc': '2021-05-07T14:35:55.507026Z', 'properties': {'ContentSnapshotId': '4d046165-648b-40de-a23c-989327fc48c6', 'StepType': 'PythonScriptStep', 'azureml.moduleid': 'b25e75e1-7075-49f9-aab5-e147c30b58de', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '8468ecf4', 'azureml.pipelinerunid': '3797e9ba-4b56-4353-bde7-972efe1aa0d4', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': '63539e99-5a72-48c0-95c8-17ea9adbb17d'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.26.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'dp-100-study-jc', 'dataReferences': {'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/09c088de-a311-4681-8490-add6939b43ac/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '63539e99-5a72-48c0-95c8-17ea9adbb17d', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'batch_environment', 'version': 'Autosave_2021-05-07T14:22:28Z_3e45d80f', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.26.0', 'azureml-core~=1.26.0', 'azureml-dataprep[fuse]']}, 'scikit-learn', 'pip'], 'name': 'azureml_9f1642b367279a8b0eac354da8f073c0'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'e ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '3797e9ba-4b56-4353-bde7-972efe1aa0d4', 'status': 'Completed', 'startTimeUtc': '2021-05-07T14:26:49.367883Z', 'endTimeUtc': '2021-05-07T14:36:04.215614Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.3797e9ba-4b56-4353-bde7-972efe1aa0d4/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=yOK9sMF%2F1KR5Uaok8WppuzzpvgA3b8cjAKTf3hJYY8k%3D&st=2021-05-07T14%3A26%3A05Z&se=2021-05-07T22%3A36%3A05Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.3797e9ba-4b56-4353-bde7-972efe1aa0d4/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=KUJv2kxKCev%2FIYyvN%2BbvZBNOGZ1anihVGSYMRO6r3rY%3D&st=2021-05-07T14%3A26%3A05Z&se=2021-05-07T22%3A36%3A05Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.3797e9ba-4b56-4353-bde7-972efe1aa0d4/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=jbVUspmimFNgPydHVCIqHaB1CycTHHMuESvdhxls67c%3D&st=2021-05-07T14%3A26%3A05Z&se=2021-05-07T22%3A36%3A05Z&sp=r'}, 'submittedBy': 'Jose Costa'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           0
# 2   100.csv           1
# 3    11.csv           1
# 4    12.csv           0
# 5    68.csv           0
# 6    69.csv           1
# 7     7.csv           0
# 8    70.csv           0
# 9    71.csv           0
# 10    5.csv           1
# 11   50.csv           0
# 12   51.csv           0
# 13   52.csv           0
# 14   53.csv           0
# 15   59.csv           1
# 16    6.csv           0
# 17   60.csv           0
# 18   61.csv           0
# 19   62.csv           0

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: c741ddd3-298b-4563-801d-1b93b6156256,
# Status: Active,
# Endpoint: https://uksouth.api.azureml.ms/pipelines/v1.0/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourceGroups/dp-100-study-jc/providers/Microsoft.MachineLearningServices/workspaces/dp-100-study-jc/PipelineRuns/PipelineSubmit/c741ddd3-298b-4563-801d-1b93b6156256)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://uksouth.api.azureml.ms/pipelines/v1.0/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourceGroups/dp-100-study-jc/providers/Microsoft.MachineLearningServices/workspaces/dp-100-study-jc/PipelineRuns/PipelineSubmit/c741ddd3-298b-4563-801d-1b93b6156256

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# '573435d6-6b0e-43c3-b77b-a139690f2bb8'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 573435d6-6b0e-43c3-b77b-a139690f2bb8
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/573435d6-6b0e-43c3-b77b-a139690f2bb8?wsid=/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourcegroups/dp-100-study-jc/workspaces/dp-100-study-jc&tid=d51de596-45a0-4aa5-a0d8-47d1c958aa32
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '573435d6-6b0e-43c3-b77b-a139690f2bb8', 'status': 'Completed', 'startTimeUtc': '2021-05-07T14:36:17.272612Z', 'endTimeUtc': '2021-05-07T14:36:19.265874Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'c741ddd3-298b-4563-801d-1b93b6156256'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.573435d6-6b0e-43c3-b77b-a139690f2bb8/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=cT92Dxp7kNiPkkixsjAZuOwWcMQTxj9eDhyYLlWnhdY%3D&st=2021-05-07T14%3A26%3A20Z&se=2021-05-07T22%3A36%3A20Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.573435d6-6b0e-43c3-b77b-a139690f2bb8/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=R0u%2B1PKoV1Xa0EecmBj9paVMRi7nEW5y7OmIoBBsa7Y%3D&st=2021-05-07T14%3A26%3A20Z&se=2021-05-07T22%3A36%3A20Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.573435d6-6b0e-43c3-b77b-a139690f2bb8/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=yIxWZHbf3cQNgcT12zQqp238bui0glw5grHFEmeqfrc%3D&st=2021-05-07T14%3A26%3A20Z&se=2021-05-07T22%3A36%3A20Z&sp=r'}, 'submittedBy': 'Jose Costa'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
# prediction_run = next(pipeline_run.get_children())
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           0
# 2   100.csv           1
# 3    11.csv           1
# 4    12.csv           0
# 5    68.csv           0
# 6    69.csv           1
# 7     7.csv           0
# 8    70.csv           0
# 9    71.csv           0
# 10    5.csv           1
# 11   50.csv           0
# 12   51.csv           0
# 13   52.csv           0
# 14   53.csv           0
# 15   59.csv           1
# 16    6.csv           0
# 17   60.csv           0
# 18   61.csv           0
# 19   62.csv           0

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
