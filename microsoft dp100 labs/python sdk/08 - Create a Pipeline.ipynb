# %% [markdown]
# # Create a Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets, either on-demand by a user, from an automated build process, or on a schedule.
#
# In this notebook, you'll bring together all of these elements to create a simple pipeline that pre-processes data and then trains and registers a model.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.26.0 to work with dp-100-study-jc

# %% [markdown]
# ## Prepare data
#
# In your pipeline, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if you created it in previously, the code will find the existing version)

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(
        files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
        target_path='diabetes-data/', # Put it in a folder path in the datastore
        overwrite=True, # Replace existing files of the same name
        show_progress=True
    )

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(
            workspace=ws, 
            name='diabetes dataset',
            description='diabetes data',
            tags={'format':'CSV'},
            create_new_version=True
        )
        print('Dataset registered.')
        
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create scripts for pipeline steps
#
# Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like a data transfer step that copies data from one location to another. Each step can run in its own compute context. In this exercise, you'll build a simple pipeline that contains two Python script steps: one to pre-process some training data, and another to use the pre-processed data to train and register a model.
#
# First, let's create a folder for the script files we'll use in the pipeline steps.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# Now let's create the first script, which will read data from the diabetes dataset and apply some simple pre-processing to remove any rows with missing data and normalize the numeric features so they're on a similar scale.
#
# The script includes a argument named **--prepped-data**, which references the folder where the resulting data should be saved.

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Writing diabetes_pipeline/prep_diabetes.py

# %% [markdown]
# Now you can create the script for the second step, which will train a model. The script includes a argument named **--training-folder**, which references the folder where the prepared data was saved by the previous step.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-folder", type=str, dest='training_folder', help='training data folder')
args = parser.parse_args()
training_folder = args.training_folder

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_folder,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values
y = diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Writing diabetes_pipeline/train_diabetes.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps
#
# In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, get the compute target you created in a previous lab (if it doesn't exist, it will be created).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "dp-100-study-jc"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so you'll need to create a run configuration.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment 
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline
#
# Now you're ready to create and run a pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to be passed between them. In this case, the first step must write the prepared data to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so our code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
prepped_data_folder = PipelineData(
    "prepped_data_folder", 
    datastore = ws.get_default_datastore()
)

# Step 1, Run the data prep script
prep_step = PythonScriptStep(
    name = "Prepare Data",
    source_directory = experiment_folder,
    script_name = "prep_diabetes.py",
    arguments = [
        '--input-data', diabetes_ds.as_named_input('raw_data'),
        '--prepped-data', prepped_data_folder
    ],
    outputs=[prepped_data_folder],
    compute_target = pipeline_cluster,
    runconfig = pipeline_run_config,
    allow_reuse = True
)

# Step 2, run the training script
train_step = PythonScriptStep(
    name = "Train and Register Model",
    source_directory = experiment_folder,
    script_name = "train_diabetes.py",
    arguments = [
        '--training-folder', prepped_data_folder
    ],
    inputs=[prepped_data_folder],
    compute_target = pipeline_cluster,
    runconfig = pipeline_run_config,
    allow_reuse = True
)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, you're ready build the pipeline from the steps you've defined and run it as an experiment.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [prep_step, train_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [c9aab080][32f4255a-e6b4-4c88-bd00-b244109c9740], (This step will run and generate new outputs)
# Created step Train and Register Model [1299741c][6f2e037a-5ee6-4d0f-b921-6978715a1cab], (This step will run and generate new outputs)
# Submitted PipelineRun c5eeac3d-4d07-409a-a5f1-15ae2d9f92a0
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/c5eeac3d-4d07-409a-a5f1-15ae2d9f92a0?wsid=/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourcegroups/dp-100-study-jc/workspaces/dp-100-study-jc&tid=d51de596-45a0-4aa5-a0d8-47d1c958aa32
# Pipeline submitted for execution.
# PipelineRunId: c5eeac3d-4d07-409a-a5f1-15ae2d9f92a0
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/c5eeac3d-4d07-409a-a5f1-15ae2d9f92a0?wsid=/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourcegroups/dp-100-study-jc/workspaces/dp-100-study-jc&tid=d51de596-45a0-4aa5-a0d8-47d1c958aa32
# PipelineRun Status: NotStarted
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRun Status: Running
#
#
# StepRunId: 546928d5-035d-4bdc-9529-ea5895ca0437
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/546928d5-035d-4bdc-9529-ea5895ca0437?wsid=/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourcegroups/dp-100-study-jc/workspaces/dp-100-study-jc&tid=d51de596-45a0-4aa5-a0d8-47d1c958aa32
# StepRun( Prepare Data ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/05/05 16:43:37 Downloading source code...
# 2021/05/05 16:43:38 Finished downloading source code
# 2021/05/05 16:43:39 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/05/05 16:43:39 Successfully set up Docker network: acb_default_network
# 2021/05/05 16:43:39 Setting up Docker configuration...
# 2021/05/05 16:43:39 Successfully set up Docker configuration
# 2021/05/05 16:43:39 Logging in to registry: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io
# 2021/05/05 16:43:40 Successfully logged into 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io
# 2021/05/05 16:43:40 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/05 16:43:40 Scanning for dependencies...
# 2021/05/05 16:43:41 Successfully scanned dependencies
# 2021/05/05 16:43:41 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#  ---> c942df5ba5d0
# Step 2/18 : USER root
#  ---> Running in bca629770da8
# Removing intermediate container bca629770da8
#  ---> 56347350b4dd
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 0f8e847c6625
# Removing intermediate container 0f8e847c6625
#  ---> f2fef503cb4a
# Step 4/18 : WORKDIR /
#  ---> Running in 880728078abe
# Removing intermediate container 880728078abe
#  ---> 140c2ead4e50
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 14ddd0418cce
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 5223dd84ea7a
# Removing intermediate container 5223dd84ea7a
#  ---> 3e0f5c1ebe40
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
# StepRun( Prepare Data ) Status: Running
#  ---> d76240260683
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in c73e534ca173
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ######8    |  68%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######     |  61%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# jupyter_client-6.1.7 | 76 KB     |            |   0%
# jupyter_client-6.1.7 | 76 KB     | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | #######5   |  75%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | ########5  |  85%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | ########## | 100%
# pillow-8.0.0         | 675 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 4          |   5%
# qt-5.9.6             | 86.7 MB   | #          |  11%
# qt-5.9.6             | 86.7 MB   | ##1        |  21%
# qt-5.9.6             | 86.7 MB   | ###3       |  33%
# qt-5.9.6             | 86.7 MB   | ####6      |  47%
# qt-5.9.6             | 86.7 MB   | #####8     |  59%
# qt-5.9.6             | 86.7 MB   | ######8    |  68%
# qt-5.9.6             | 86.7 MB   | #######9   |  80%
# qt-5.9.6             | 86.7 MB   | ########9  |  90%
# qt-5.9.6             | 86.7 MB   | #########8 |  99%
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# prompt-toolkit-3.0.8 | 244 KB    |            |   0%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | #1         |  11%
# icu-58.2             | 22.7 MB   | ###        |  30%
# icu-58.2             | 22.7 MB   | #####      |  50%
# icu-58.2             | 22.7 MB   | ########   |  80%
# icu-58.2             | 22.7 MB   | ########## | 100%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# pyzmq-19.0.2         | 479 KB    |            |   0%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | 6          |   7%
# scikit-learn-0.23.2  | 6.9 MB    | ######2    |  63%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | ########7  |  88%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# pygments-2.7.1       | 704 KB    |            |   0%
# pygments-2.7.1       | 704 KB    | ########## | 100%
# pygments-2.7.1       | 704 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   2%
# mkl-2019.4           | 204.1 MB  | 6          |   6%
# mkl-2019.4           | 204.1 MB  | #          |  11%
# mkl-2019.4           | 204.1 MB  | #4         |  14%
# mkl-2019.4           | 204.1 MB  | #8         |  18%
# mkl-2019.4           | 204.1 MB  | ##1        |  21%
# mkl-2019.4           | 204.1 MB  | ##4        |  24%
# mkl-2019.4           | 204.1 MB  | ##9        |  30%
# mkl-2019.4           | 204.1 MB  | ###3       |  34%
# mkl-2019.4           | 204.1 MB  | ###7       |  37%
# mkl-2019.4           | 204.1 MB  | ####1      |  41%
# mkl-2019.4           | 204.1 MB  | ####6      |  47%
# mkl-2019.4           | 204.1 MB  | #####1     |  51%
# mkl-2019.4           | 204.1 MB  | #####5     |  55%
# mkl-2019.4           | 204.1 MB  | #####8     |  59%
# mkl-2019.4           | 204.1 MB  | ######1    |  62%
# mkl-2019.4           | 204.1 MB  | ######6    |  66%
# mkl-2019.4           | 204.1 MB  | ######9    |  70%
# mkl-2019.4           | 204.1 MB  | #######3   |  74%
# mkl-2019.4           | 204.1 MB  | #######8   |  79%
# mkl-2019.4           | 204.1 MB  | ########3  |  83%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# zeromq-4.3.3         | 678 KB    |            |   0%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | #######    |  70%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | ########## | 100%
# jedi-0.17.2          | 952 KB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########8  |  88%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #          |  10%
# python-3.6.2         | 27.0 MB   | ##9        |  30%
# python-3.6.2         | 27.0 MB   | ####7      |  47%
# python-3.6.2         | 27.0 MB   | ######7    |  67%
# python-3.6.2         | 27.0 MB   | #######9   |  79%
# python-3.6.2         | 27.0 MB   | #########7 |  98%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ###7       |  38%
# scipy-1.5.2          | 18.5 MB   | #######7   |  78%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.xo2lnkse.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.26.0
#   Downloading azureml_defaults-1.26.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.15.0-py3-none-any.whl (39.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-4.0.0-cp36-cp36m-manylinux2014_x86_64.whl (21.9 MB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-core~=1.26.0
#   Downloading azureml_core-1.26.0-py3-none-any.whl (2.2 MB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.26.0
#   Downloading azureml_dataset_runtime-1.26.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-dataprep-native<34.0.0,>=33.0.0
#   Downloading azureml_dataprep_native-33.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-rslex<1.14.0a,>=1.13.0dev0
#   Downloading azureml_dataprep_rslex-1.13.0-cp36-cp36m-manylinux1_x86_64.whl (9.8 MB)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.xo2lnkse.requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.xo2lnkse.requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.26.0->-r /azureml-environment-setup/condaenv.xo2lnkse.requirements.txt (line 1)) (2020.1)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting adal>=0.4.5
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.26.0->-r /azureml-environment-setup/condaenv.xo2lnkse.requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.3 in /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.26.0->-r /azureml-environment-setup/condaenv.xo2lnkse.requirements.txt (line 1)) (2.8.1)
# Collecting requests>=2.17.3
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting docker
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.1.0-py2.py3-none-any.whl (1.1 MB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.13.0-py2.py3-none-any.whl (133 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.11.0-py2.py3-none-any.whl (63 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/lib/python3.6/site-packages (from requests>=2.17.3->azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.26.0->-r /azureml-environment-setup/condaenv.xo2lnkse.requirements.txt (line 1)) (2020.6.20)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.59.0-py2.py3-none-any.whl (67 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.0.1-py3-none-any.whl (16 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Building wheels for collected packages: json-logging-py, liac-arff, fusepy
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=b3626dc10d40a332471568d7708f08873c5a8af50ed29c568d38771e11fa3671
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=77470c141293fae3ef9114b57ff05868a0d3260399ecd20ac1f2c4041890ea44
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=b7fb5226c9bfb3a3b97ccd815a298fc8055f534fca7b217cd1975cb09514de70
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built json-logging-py liac-arff fusepy
# Installing collected packages: werkzeug, dill, PyJWT, idna, urllib3, chardet, requests, pycparser, cffi, cryptography, adal, liac-arff, azureml-model-management-sdk, itsdangerous, click, MarkupSafe, Jinja2, flask, json-logging-py, configparser, oauthlib, requests-oauthlib, isodate, msrest, jeepney, SecretStorage, contextlib2, azure-common, websocket-client, docker, typing-extensions, zipp, importlib-metadata, jsonpickle, msrestazure, azure-mgmt-authorization, azure-mgmt-storage, azure-graphrbac, pyopenssl, azure-mgmt-keyvault, backports.weakref, backports.tempfile, pyasn1, ndg-httpsclient, jmespath, azure-mgmt-resource, azure-mgmt-containerregistry, pathspec, ruamel.yaml.clib, ruamel.yaml, azureml-core, gunicorn, applicationinsights, pyarrow, azureml-dataprep-native, cloudpickle, portalocker, msal, msal-extensions, azure-core, azure-identity, distro, dotnetcore2, azureml-dataprep-rslex, azureml-dataprep, fusepy, azureml-dataset-runtime, azureml-defaults
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.13.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.1.0 azure-mgmt-storage-11.2.0 azureml-core-1.26.0 azureml-dataprep-2.15.0 azureml-dataprep-native-33.0.0 azureml-dataprep-rslex-1.13.0 azureml-dataset-runtime-1.26.0 azureml-defaults-1.26.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.7 dill-0.3.3 distro-1.5.0 docker-5.0.0 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-4.0.1 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.11.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 portalocker-1.7.1 pyarrow-4.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 typing-extensions-3.10.0.0 urllib3-1.26.4 websocket-client-0.59.0 werkzeug-1.0.1 zipp-3.4.1
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container c73e534ca173
#  ---> dc6382989d73
# Step 9/18 : ENV PATH /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/bin:$PATH
#  ---> Running in 702307d5d207
# Removing intermediate container 702307d5d207
#  ---> 27d751e365b1
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 33c011f4e614
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 04fef1540b7c
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b
#  ---> Running in 7693a276639e
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 7693a276639e
#  ---> ecedff5cfe27
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b
#  ---> Running in 3a33f99184c8
# Removing intermediate container 3a33f99184c8
#  ---> cb55ed5f7e90
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/lib:$LD_LIBRARY_PATH
#  ---> Running in c07f3294f82a
# Removing intermediate container c07f3294f82a
#  ---> 079684cbf0ba
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 8173fbe08c29
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in b9ede2c0766c
# Removing intermediate container b9ede2c0766c
#  ---> 3b2c4b0da1f4
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in c83d1617695e
# Removing intermediate container c83d1617695e
#  ---> faebc75f4846
# Step 18/18 : CMD ["bash"]
#  ---> Running in 14b08368aac9
# Removing intermediate container 14b08368aac9
#  ---> fbb18d60bef4
# Successfully built fbb18d60bef4
# Successfully tagged 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_39bfe367f5cafce04c92eec7251a9084:latest
# Successfully tagged 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_39bfe367f5cafce04c92eec7251a9084:1
# 2021/05/05 16:48:08 Successfully executed container: acb_step_0
# 2021/05/05 16:48:08 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/05 16:48:08 Pushing image: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_39bfe367f5cafce04c92eec7251a9084:1, attempt 1
# The push refers to repository [94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_39bfe367f5cafce04c92eec7251a9084]
# 3784161e11c9: Preparing
# 48ad8702d578: Preparing
# bbb9e6fae925: Preparing
# 5d7573b672b1: Preparing
# f3efb7556161: Preparing
# d89fabe6fec1: Preparing
# 78180b241c17: Preparing
# 98a392900d4f: Preparing
# 4dfb359a8ab4: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# d89fabe6fec1: Waiting
# 78180b241c17: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# 4dfb359a8ab4: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# 98a392900d4f: Waiting
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# bbb9e6fae925: Pushed
# 3784161e11c9: Pushed
# 5d7573b672b1: Pushed
# 48ad8702d578: Pushed
# d89fabe6fec1: Pushed
# 98a392900d4f: Pushed
# 78180b241c17: Pushed
# 4dfb359a8ab4: Pushed
# 3f3f8889d538: Pushed
# 420340de7040: Pushed
# c3d9b0d7dd4c: Pushed
# 18c9012f327d: Pushed
# 4441896e1280: Pushed
# 0d34930f20d5: Pushed
# 5276d2b930fc: Pushed
# e6feec0db89a: Pushed
# 697949baa658: Pushed
# a64fe594a899: Pushed
# e4a0bf630548: Pushed
# 935c56d8b3f9: Pushed
#
# f3efb7556161: Pushed
# 1: digest: sha256:f6cea5c50c487577623e30f9802154f7df92070031620e3e5138ccd91945ee03 size: 4721
# 2021/05/05 16:50:38 Successfully pushed image: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_39bfe367f5cafce04c92eec7251a9084:1
# 2021/05/05 16:50:38 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/05 16:50:38 Pushing image: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_39bfe367f5cafce04c92eec7251a9084:latest, attempt 1
# The push refers to repository [94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_39bfe367f5cafce04c92eec7251a9084]
# 3784161e11c9: Preparing
# 48ad8702d578: Preparing
# bbb9e6fae925: Preparing
# 5d7573b672b1: Preparing
# f3efb7556161: Preparing
# d89fabe6fec1: Preparing
# 78180b241c17: Preparing
# 98a392900d4f: Preparing
# 4dfb359a8ab4: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# d89fabe6fec1: Waiting
# 78180b241c17: Waiting
# 98a392900d4f: Waiting
# 4dfb359a8ab4: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# f3efb7556161: Layer already exists
# 3784161e11c9: Layer already exists
# 48ad8702d578: Layer already exists
# bbb9e6fae925: Layer already exists
# d89fabe6fec1: Layer already exists
# 78180b241c17: Layer already exists
# 98a392900d4f: Layer already exists
# 5d7573b672b1: Layer already exists
# 4dfb359a8ab4: Layer already exists
# 420340de7040: Layer already exists
# 4441896e1280: Layer already exists
# c3d9b0d7dd4c: Layer already exists
# 3f3f8889d538: Layer already exists
# a64fe594a899: Layer already exists
# 0d34930f20d5: Layer already exists
# e4a0bf630548: Layer already exists
# 18c9012f327d: Layer already exists
# 5276d2b930fc: Layer already exists
# 935c56d8b3f9: Layer already exists
# 697949baa658: Layer already exists
# e6feec0db89a: Layer already exists
# latest: digest: sha256:f6cea5c50c487577623e30f9802154f7df92070031620e3e5138ccd91945ee03 size: 4721
# 2021/05/05 16:50:45 Successfully pushed image: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_39bfe367f5cafce04c92eec7251a9084:latest
# 2021/05/05 16:50:45 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 268.103454)
# 2021/05/05 16:50:45 Populating digests for step ID: acb_step_0...
# 2021/05/05 16:50:50 Successfully populated digests for step ID: acb_step_0
# 2021/05/05 16:50:50 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 149.755941)
# 2021/05/05 16:50:50 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 6.513290)
# 2021/05/05 16:50:50 The following dependencies were found:
# 2021/05/05 16:50:50
# - image:
#     registry: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io
#     repository: azureml/azureml_39bfe367f5cafce04c92eec7251a9084
#     tag: latest
#     digest: sha256:f6cea5c50c487577623e30f9802154f7df92070031620e3e5138ccd91945ee03
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
# - image:
#     registry: 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io
#     repository: azureml/azureml_39bfe367f5cafce04c92eec7251a9084
#     tag: "1"
#     digest: sha256:f6cea5c50c487577623e30f9802154f7df92070031620e3e5138ccd91945ee03
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
#
#
# Run ID: db2 was successful after 7m13s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_59dacfb0f60d5d85e4c106fb735c767f3fdd5d7adb7cd2f2b217d08e0a4ecad2_d.txt
# ========================================================================================================================
# 2021-05-05T16:51:44Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/546928d5-035d-4bdc-9529-ea5895ca0437/mounts/workspaceblobstore
# 2021-05-05T16:51:44Z Starting output-watcher...
# 2021-05-05T16:51:44Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-05T16:51:45Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-05-05T16:51:45Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_39bfe367f5cafce04c92eec7251a9084
# 4007a89234b4: Already exists
# 5dfa26c6b9c9: Already exists
# 0ba7bf18aa40: Already exists
# 4c6ec688ebe3: Already exists
# 574f361512d6: Already exists
# db4d1e2d7079: Already exists
# e544ee0f522d: Already exists
# c655136086be: Already exists
# 2ec37f44090c: Already exists
# 5fba3bd4a2c4: Already exists
# 7e0ea9d0a1ab: Already exists
# da005f826951: Already exists
# 4c3bf41c4c41: Pulling fs layer
# 08088c4cf693: Pulling fs layer
# a1e46c060645: Pulling fs layer
# ea678e44d275: Pulling fs layer
# bc72b9909563: Pulling fs layer
# 33ba48d9d6c1: Pulling fs layer
# 57da3fb35239: Pulling fs layer
# 7bd54dbae23a: Pulling fs layer
# 14999cce6780: Pulling fs layer
# ea678e44d275: Waiting
# bc72b9909563: Waiting
# 33ba48d9d6c1: Waiting
# 57da3fb35239: Waiting
# 7bd54dbae23a: Waiting
# 14999cce6780: Waiting
# 4c3bf41c4c41: Verifying Checksum
# 4c3bf41c4c41: Download complete
# 08088c4cf693: Verifying Checksum
# 08088c4cf693: Download complete
# a1e46c060645: Verifying Checksum
# a1e46c060645: Download complete
# 4c3bf41c4c41: Pull complete
# ea678e44d275: Verifying Checksum
# ea678e44d275: Download complete
# 33ba48d9d6c1: Verifying Checksum
# 33ba48d9d6c1: Download complete
# 08088c4cf693: Pull complete
# a1e46c060645: Pull complete
# 57da3fb35239: Verifying Checksum
# 57da3fb35239: Download complete
# ea678e44d275: Pull complete
# 7bd54dbae23a: Verifying Checksum
# 7bd54dbae23a: Download complete
# 14999cce6780: Verifying Checksum
# 14999cce6780: Download complete
# bc72b9909563: Verifying Checksum
# bc72b9909563: Download complete
# bc72b9909563: Pull complete
# 33ba48d9d6c1: Pull complete
# 57da3fb35239: Pull complete
# 7bd54dbae23a: Pull complete
# 14999cce6780: Pull complete
# Digest: sha256:f6cea5c50c487577623e30f9802154f7df92070031620e3e5138ccd91945ee03
# Status: Downloaded newer image for 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_39bfe367f5cafce04c92eec7251a9084:latest
# 94ec91a7e3b745d69a1a55fcc54ef554.azurecr.io/azureml/azureml_39bfe367f5cafce04c92eec7251a9084:latest
# 2021-05-05T16:52:25Z Check if container 546928d5-035d-4bdc-9529-ea5895ca0437 already exist exited with 0,
#
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/05/05 16:52:39 Starting App Insight Logger for task:  runTaskLet
# 2021/05/05 16:52:39 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/05/05 16:52:39 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-05-05T16:52:40.003778] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['prep_diabetes.py', '--input-data', '70e13bd0-acd9-4e57-87a8-6579c01bc98a', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/546928d5-035d-4bdc-9529-ea5895ca0437/mounts/workspaceblobstore/azureml/546928d5-035d-4bdc-9529-ea5895ca0437/prepped_data_folder'])
# Script type = None
# [2021-05-05T16:52:41.988226] Entering Run History Context Manager.
# [2021-05-05T16:52:42.665110] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/546928d5-035d-4bdc-9529-ea5895ca0437/mounts/workspaceblobstore/azureml/546928d5-035d-4bdc-9529-ea5895ca0437
# [2021-05-05T16:52:42.665419] Preparing to call script [prep_diabetes.py] with arguments:['--input-data', '70e13bd0-acd9-4e57-87a8-6579c01bc98a', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/546928d5-035d-4bdc-9529-ea5895ca0437/mounts/workspaceblobstore/azureml/546928d5-035d-4bdc-9529-ea5895ca0437/prepped_data_folder']
# [2021-05-05T16:52:42.665475] After variable expansion, calling script [prep_diabetes.py] with arguments:['--input-data', '70e13bd0-acd9-4e57-87a8-6579c01bc98a', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/546928d5-035d-4bdc-9529-ea5895ca0437/mounts/workspaceblobstore/azureml/546928d5-035d-4bdc-9529-ea5895ca0437/prepped_data_folder']
#
# Loading Data...
# 2021/05/05 16:52:44 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# Saving Data...
#
#
# [2021-05-05T16:52:57.148320] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.1409740447998047 seconds
# [2021-05-05T16:52:57.483837] Finished context manager injector.
# 2021/05/05 16:53:03 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2021/05/05 16:53:03 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 2
# FilteredData: 0.
# 2021/05/05 16:53:03 Process Exiting with Code:  0
# 2021/05/05 16:53:04 All App Insights Logs was send successfully
#
# Streaming azureml-logs/75_job_post-tvmps_59dacfb0f60d5d85e4c106fb735c767f3fdd5d7adb7cd2f2b217d08e0a4ecad2_d.txt
# ===============================================================================================================
# [2021-05-05T16:53:04.901571] Entering job release
# [2021-05-05T16:53:06.120118] Starting job release
# [2021-05-05T16:53:06.121425] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 333
# [2021-05-05T16:53:06.121909] job release stage : upload_datastore starting...
# [2021-05-05T16:53:06.125295] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-05T16:53:06.132885] job release stage : execute_job_release starting...
# [2021-05-05T16:53:06.133582] job release stage : copy_batchai_cached_logs starting...
# [2021-05-05T16:53:06.133884] job release stage : copy_batchai_cached_logs completed...
# [2021-05-05T16:53:06.135572] Entering context manager injector.
# [2021-05-05T16:53:06.161872] job release stage : upload_datastore completed...
# [2021-05-05T16:53:06.286583] job release stage : execute_job_release completed...
# [2021-05-05T16:53:06.298396] job release stage : send_run_telemetry starting...
# [2021-05-05T16:53:06.441398] get vm size and vm region successfully.
# [2021-05-05T16:53:06.663499] get compute meta data successfully.
# [2021-05-05T16:53:06.937680] post artifact meta request successfully.
# [2021-05-05T16:53:06.962153] upload compute record artifact successfully.
# [2021-05-05T16:53:06.962251] job release stage : send_run_telemetry completed...
# [2021-05-05T16:53:06.962582] Job release is complete
#
# StepRun(Prepare Data) Execution Summary
# ========================================
# StepRun( Prepare Data ) Status: Finished
# ...
# >>>   2021/05/05 16:53:41 Check if container 87ec64d0-c9a1-4a66-aca1-41e28342b62d already exist exited with 0,
# >>>
# >>>   2021/05/05 16:53:41 Check if container 87ec64d0-c9a1-4a66-aca1-41e28342b62d already exist exited with 0,
# >>>
# >>>   2021/05/05 16:53:41 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/05/05 16:53:41 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/05/05 16:53:41 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-bf8f854938199bb8d1f4967db90d6670-db64c86d5a2b8823-01 -sshRequired=false]
# >>>   2021/05/05 16:53:41 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-bf8f854938199bb8d1f4967db90d6670-db64c86d5a2b8823-01 -sshRequired=false]
# >>>   2021/05/05 16:53:42 Container ssh is not required for job type.
# >>>   2021/05/05 16:53:42 Starting docker container succeeded.
# >>>   2021/05/05 16:53:42 Starting docker container succeeded.
# >>>   2021/05/05 16:53:42 Disk space after starting docker container: 26247MB
# >>>   2021/05/05 16:53:42 Begin execution of runSpecialJobTask
# >>>   2021/05/05 16:53:42 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/mounts/workspaceblobstore/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/azureml_compute_logs
# >>>   2021/05/05 16:53:42 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/bin/python /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/mounts/workspaceblobstore/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"cb30600d-21d9-4193-8786-84ab6a1bb9b3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/05 16:53:42 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/mounts/workspaceblobstore/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/azureml_compute_logs/65_job_prep-tvmps_59dacfb0f60d5d85e4c106fb735c767f3fdd5d7adb7cd2f2b217d08e0a4ecad2_d.txt
# >>>   2021/05/05 16:53:42 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/mounts/workspaceblobstore/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/azureml_compute_logs/65_job_prep-tvmps_59dacfb0f60d5d85e4c106fb735c767f3fdd5d7adb7cd2f2b217d08e0a4ecad2_d.txt
# >>>   2021/05/05 16:53:42 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/22c49dc3-8faf-411d-88b6-172011e3f431/job-1/87ec64d0-c9a1-4a66-a_92fd93b8-937f-4e05-89f9-f404760ab0a8/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/mounts/workspaceblobstore/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d;/azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/bin/python /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/mounts/workspaceblobstore/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"cb30600d-21d9-4193-8786-84ab6a1bb9b3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/05 16:53:42 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/05/05 16:53:42 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-bf8f854938199bb8d1f4967db90d6670-1e154c4a3d4ee84e-01 -t 87ec64d0-c9a1-4a66-aca1-41e28342b62d bash -c source /etc/bash.bashrc; PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/22c49dc3-8faf-411d-88b6-172011e3f431/job-1/87ec64d0-c9a1-4a66-a_92fd93b8-937f-4e05-89f9-f404760ab0a8/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/mounts/workspaceblobstore/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d;/azureml-envs/azureml_276d4387c14eee3c6b95058c39777b6b/bin/python /mnt/batch/tasks/shared/LS_root/jobs/dp-100-study-jc/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d/mounts/workspaceblobstore/azureml/87ec64d0-c9a1-4a66-aca1-41e28342b62d-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"cb30600d-21d9-4193-8786-84ab6a1bb9b3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/05 16:53:42 Attempt 1 of http call to https://uksouth.api.azureml.ms/history/v1.0/private/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourceGroups/dp-100-study-jc/providers/Microsoft.MachineLearningServices/workspaces/dp-100-study-jc/runs/87ec64d0-c9a1-4a66-aca1-41e28342b62d/spans
# >>>   2021/05/05 16:53:45 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:42.603588] Entering job preparation.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:43.885223] Starting job preparation.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:43.885261] Extracting the control code.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:43.901795] fetching and extracting the control code on master node.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:43.901832] Starting extract_project.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:43.901952] Starting to extract zip file.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.340076] Finished extracting zip file.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.466833] Using urllib.request Python 3.0 or later
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.466895] Start fetching snapshots.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.466934] Start fetching snapshot.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.466945] Retrieving project from snapshot: cb30600d-21d9-4193-8786-84ab6a1bb9b3
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 44
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.719155] Finished fetching snapshot.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.719190] Finished fetching snapshots.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.719200] Finished extract_project.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.729444] Finished fetching and extracting the control code.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.733673] downloadDataStore - Download from datastores if requested.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.735425] Start run_history_prep.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:44.788350] Entering context manager injector.
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: Acquired lockfile /tmp/87ec64d0-c9a1-4a66-aca1-41e28342b62d-datastore.lock to downloading input data references
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:45.337969] downloadDataStore completed
# >>>   2021/05/05 16:53:45 runSpecialJobTask: preparation: [2021-05-05T16:53:45.342311] Job preparation is complete.
# >>>   2021/05/05 16:53:45 Execution of runSpecialJobTask completed
# >>>   2021/05/05 16:53:45 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/05/05 16:53:45 Process Exiting with Code:  0
# >>>   2021/05/05 16:53:45 All App Insights Logs was send successfully
# >>>
# 2021-05-05T16:53:46Z 127.0.0.1 slots=2 max-slots=2
# 2021-05-05T16:53:46Z launching Custom job
#
# Streaming azureml-logs/75_job_post-tvmps_59dacfb0f60d5d85e4c106fb735c767f3fdd5d7adb7cd2f2b217d08e0a4ecad2_d.txt
# ===============================================================================================================
# [2021-05-05T16:53:59.816970] Entering job release
# [2021-05-05T16:54:01.016005] Starting job release
# [2021-05-05T16:54:01.020780] Logging experiment finalizing status in history service.
# [2021-05-05T16:54:01.020969] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 147
# [2021-05-05T16:54:01.022171] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-05T16:54:01.022479] job release stage : execute_job_release starting...
# [2021-05-05T16:54:01.025019] job release stage : copy_batchai_cached_logs starting...
# [2021-05-05T16:54:01.031834] job release stage : copy_batchai_cached_logs completed...
# [2021-05-05T16:54:01.033007] Entering context manager injector.
# [2021-05-05T16:54:01.057787] job release stage : upload_datastore completed...
# [2021-05-05T16:54:01.181283] job release stage : execute_job_release completed...
# [2021-05-05T16:54:01.189623] job release stage : send_run_telemetry starting...
# [2021-05-05T16:54:01.332024] get vm size and vm region successfully.
# [2021-05-05T16:54:01.506497] get compute meta data successfully.
# [2021-05-05T16:54:01.648046] post artifact meta request successfully.
# [2021-05-05T16:54:01.672944] upload compute record artifact successfully.
# [2021-05-05T16:54:01.673037] job release stage : send_run_telemetry completed...
# [2021-05-05T16:54:01.673486] Job release is complete
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': '87ec64d0-c9a1-4a66-aca1-41e28342b62d', 'target': 'dp-100-study-jc', 'status': 'Completed', 'startTimeUtc': '2021-05-05T16:53:36.533305Z', 'endTimeUtc': '2021-05-05T16:54:09.806761Z', 'properties': {'ContentSnapshotId': 'cb30600d-21d9-4193-8786-84ab6a1bb9b3', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '6f2e037a-5ee6-4d0f-b921-6978715a1cab', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '1299741c', 'azureml.pipelinerunid': 'c5eeac3d-4d07-409a-a5f1-15ae2d9f92a0', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-folder', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'dp-100-study-jc', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/546928d5-035d-4bdc-9529-ea5895ca0437/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.26.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_276d4387c14eee3c6b95058c39777b6b'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_59dacfb0f60d5d85e4c106fb735c767f3fdd5d7adb7cd2f2b217d08e0a4ecad2_d.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.87ec64d0-c9a1-4a66-aca1-41e28342b62d/azureml-logs/55_azureml-execution-tvmps_59dacfb0f60d5d85e4c106fb735c767f3fdd5d7adb7cd2f2b217d08e0a4ecad2_d.txt?sv=2019-02-02&sr=b&sig=OPjVpWvvG4VTWm0gs%2Bi5orsuJ%2FuM8Ag7%2FcToRhf%2F%2BA0%3D&st=2021-05-05T16%3A44%3A03Z&se=2021 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'c5eeac3d-4d07-409a-a5f1-15ae2d9f92a0', 'status': 'Completed', 'startTimeUtc': '2021-05-05T16:43:24.247174Z', 'endTimeUtc': '2021-05-05T16:54:17.907207Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.c5eeac3d-4d07-409a-a5f1-15ae2d9f92a0/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=w9%2BAhhgqYMt7AElVKjSf086sO9cagfpKyR8OPsbEOgo%3D&st=2021-05-05T16%3A33%3A44Z&se=2021-05-06T00%3A43%3A44Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.c5eeac3d-4d07-409a-a5f1-15ae2d9f92a0/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=DFlsh3uD%2Fwm15qGICqszDHf%2BjqxVZIPBI%2FyeHlSwzes%3D&st=2021-05-05T16%3A33%3A44Z&se=2021-05-06T00%3A43%3A44Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.c5eeac3d-4d07-409a-a5f1-15ae2d9f92a0/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=7qA%2FbEVrTz7E3GXUBBawgM22t%2Bs4d41p39FW%2Fq4CVak%3D&st=2021-05-05T16%3A33%3A44Z&se=2021-05-06T00%3A43%3A44Z&sp=r'}, 'submittedBy': 'Jose Costa'}
# 'Finished'

# %% [markdown]
# A graphical representation of the pipeline experiment will be displayed in the widget as it runs. Keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, you can examine the metrics recorded by it's child runs.

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.8997777777777778
# 	 AUC : 0.8849198062999414
# 	 ROC : aml://artifactId/ExperimentRun/dcid.87ec64d0-c9a1-4a66-aca1-41e28342b62d/ROC_1620233630.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %% [markdown]
# Assuming the pipeline was successful, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 5
# 	 Training context : Pipeline
# 	 AUC : 0.8849198062999414
# 	 Accuracy : 0.8997777777777778

# %% [markdown]
# ## Publish the pipeline
#
# After you've created and tested a pipeline, you can publish it as a REST service.

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="diabetes-training-pipeline", description="Trains diabetes model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: diabetes-training-pipeline,
# Id: ad31c3d2-0f0f-4729-884c-0d202f701e3d,
# Status: Active,
# Endpoint: https://uksouth.api.azureml.ms/pipelines/v1.0/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourceGroups/dp-100-study-jc/providers/Microsoft.MachineLearningServices/workspaces/dp-100-study-jc/PipelineRuns/PipelineSubmit/ad31c3d2-0f0f-4729-884c-0d202f701e3d)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the **Endpoints** page (on the **Pipeline Endpoints** tab) in [Azure Machine Learning studio](https://ml.azure.com). You can also find its URI as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://uksouth.api.azureml.ms/pipelines/v1.0/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourceGroups/dp-100-study-jc/providers/Microsoft.MachineLearningServices/workspaces/dp-100-study-jc/PipelineRuns/PipelineSubmit/ad31c3d2-0f0f-4729-884c-0d202f701e3d

# %% [markdown]
# ## Call the pipeline endpoint
#
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
# Object with Authorization key and Bearer token
auth_header = interactive_auth.get_authentication_header()
print("Authentication header ready.")
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

experiment_name = 'mslearn-diabetes-pipeline'

rest_endpoint = published_pipeline.endpoint
# No changes in the data, so the pipeline will use cached runs
response = requests.post(
    rest_endpoint, 
    headers=auth_header, 
    json={"ExperimentName": experiment_name}
)
run_id = response.json()["Id"]
run_id
# Out:
# '2c139666-5326-43cd-b58a-ca7279e7d4e6'

# %% [markdown]
# Since you have the run ID, you can use it to wait for the run to complete.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this course. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 2c139666-5326-43cd-b58a-ca7279e7d4e6
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/2c139666-5326-43cd-b58a-ca7279e7d4e6?wsid=/subscriptions/df741348-6c47-45d1-9bfc-1b8dbf6a4efa/resourcegroups/dp-100-study-jc/workspaces/dp-100-study-jc&tid=d51de596-45a0-4aa5-a0d8-47d1c958aa32
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '2c139666-5326-43cd-b58a-ca7279e7d4e6', 'status': 'Completed', 'startTimeUtc': '2021-05-05T17:00:03.019018Z', 'endTimeUtc': '2021-05-05T17:00:12.058569Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'ad31c3d2-0f0f-4729-884c-0d202f701e3d'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.2c139666-5326-43cd-b58a-ca7279e7d4e6/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=FLwhl37zIbKfl6bFs%2F9bfNWveBPA5Dc8kU%2BpVYPP1n4%3D&st=2021-05-05T16%3A50%3A07Z&se=2021-05-06T01%3A00%3A07Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.2c139666-5326-43cd-b58a-ca7279e7d4e6/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=aQIpGpdU4%2FN%2Fn7J11Ur%2F9HMJcS%2B49ki7heFJBwB%2B26A%3D&st=2021-05-05T16%3A50%3A07Z&se=2021-05-06T01%3A00%3A07Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.2c139666-5326-43cd-b58a-ca7279e7d4e6/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=lXaLMBVXm80TflvaIL9h37YB2swY00m3Iwpn1UuAYWo%3D&st=2021-05-05T16%3A50%3A07Z&se=2021-05-06T01%3A00%3A07Z&sp=r'}, 'submittedBy': 'Jose Costa'}
# 'Finished'

# %% [markdown]
# ## Schedule the Pipeline
#
# Suppose the clinic for the diabetes patients collects new data each week, and adds it to the dataset. You could run the pipeline every week to retrain the model with the new data.

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

# Submit the Pipeline every Monday at 00:00 UTC
recurrence = ScheduleRecurrence(frequency="Week", interval=1, week_days=["Monday"], time_of_day="00:00")
weekly_schedule = Schedule.create(ws, name="weekly-diabetes-training", 
                                  description="Based on time",
                                  pipeline_id=published_pipeline.id, 
                                  experiment_name='mslearn-diabetes-pipeline', 
                                  recurrence=recurrence)
print('Pipeline scheduled.')

# %% [markdown]
# You can retrieve the schedules that are defined in the workspace like this:

# %%
schedules = Schedule.list(ws)
schedules

# %% [markdown]
# You can check the latest run like this:

# %%
pipeline_experiment = ws.experiments.get('mslearn-diabetes-pipeline')
latest_run = list(pipeline_experiment.get_runs())[0]

latest_run.get_details()
# Out:
# {'runId': '2c139666-5326-43cd-b58a-ca7279e7d4e6',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-05T17:00:03.019018Z',
#  'endTimeUtc': '2021-05-05T17:00:12.058569Z',
#  'properties': {'azureml.runsource': 'azureml.PipelineRun',
#   'runSource': 'Unavailable',
#   'runType': 'HTTP',
#   'azureml.parameters': '{}',
#   'azureml.pipelineid': 'ad31c3d2-0f0f-4729-884c-0d202f701e3d'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'logFiles': {'logs/azureml/executionlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.2c139666-5326-43cd-b58a-ca7279e7d4e6/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=FLwhl37zIbKfl6bFs%2F9bfNWveBPA5Dc8kU%2BpVYPP1n4%3D&st=2021-05-05T16%3A50%3A07Z&se=2021-05-06T01%3A00%3A07Z&sp=r',
#   'logs/azureml/stderrlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.2c139666-5326-43cd-b58a-ca7279e7d4e6/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=aQIpGpdU4%2FN%2Fn7J11Ur%2F9HMJcS%2B49ki7heFJBwB%2B26A%3D&st=2021-05-05T16%3A50%3A07Z&se=2021-05-06T01%3A00%3A07Z&sp=r',
#   'logs/azureml/stdoutlogs.txt': 'https://dp100studyjc6051113530.blob.core.windows.net/azureml/ExperimentRun/dcid.2c139666-5326-43cd-b58a-ca7279e7d4e6/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=lXaLMBVXm80TflvaIL9h37YB2swY00m3Iwpn1UuAYWo%3D&st=2021-05-05T16%3A50%3A07Z&se=2021-05-06T01%3A00%3A07Z&sp=r'},
#  'submittedBy': 'Jose Costa'}

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
